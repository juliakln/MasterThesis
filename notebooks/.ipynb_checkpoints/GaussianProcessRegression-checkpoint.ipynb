# %% [markdown]
# # Gaussian Process Regression
#
#
# **Gaussian Process Regression (GPR)** is a non-parametric approach to describe the relationships between variables without specifying the underlying distribution. By choosing Gaussian distributions to model the data, you benefit from their properties, for example that the marginal and conditional distributions are also Gaussian [1].
#
#
# ## Gaussian Process
#
# A **Gaussian Process (GP)** is a generalization of a multivariate Gaussian distribution to *infinite dimension* and used to describe a distribution over functions. It defines a prior distribution over functions from which a posterior distribution can be inferred when data is observed.
# A GP is completely specified by a mean function $m(x)$ and a covariance function $k(x,x')$ of a real process $f(x)$:
#
# $$f(x) \sim GP(m(x),k(x,x')).$$
# Usually, the mean value is set to $m(x)=0$ since the GP is flexible enough to model the mean arbitrarily well.
# The function values $f(x_1),...,f(x_n)$ are jointly Gaussian, corresponding to any number of input points $n$ [1,2,3].
#
#
# ## Kernels
#
# **Kernels** are used as *similarity measure* between objects and define the covariance matrix $\Sigma$. A kernel $k$ is a positive definite kernel function and describes the shape of the distribution as well as characteristics of the function we want to predict. If two points $x$ and $x'$ are deemed by the kernel to be similar, then we expect the output of the function at those points to be similar, too. The kernel function $k$ is a real-valued function of two arguments, $k(x,x') \in \mathbb{R}$. To retrieve the covariance matrix $\Sigma$, we evaluate $k$ on each pairwise combination of the set of points, $k: \mathbb{R}^n \times \mathbb{R}^n \rightarrow \mathbb{R},~ \Sigma = Cov(X,X') = k(x,x')$.
# The most common kernel functions are the following [2,4]:
#
# * Radial Basis Function (RBF): $k(x,x')= \sigma^2 exp(- \frac{||x-x'||^2}{2\ell^2}) $
# The RBF kernel is a stationary kernel, hence it is invariant to translations and the covariance between two points depends only on their relative positions. Scale factor $\sigma^2$ is the variance controlling vertical variation, and describing the average distance of the function away from its mean. Parameter $\ell$ determines the horizontal lengthscale ober which the function varies, and determines the reach of influence on the neighbors.
#
#
# * Linear: $k(x,x') = \sigma_b^2 + \sigma^2(x-c)(x'-c)$
# The linear kernel is a non-stationary kernel, so the covariance between two points depends on their absolute positions. Parameter $c$ determines the point on which all posterior functions hinge. The constant variance $\sigma_b$ describes how far from 0 the height of the function will be at zero, hence adding an uncertain offset to the model.
#
#
# * Periodic: $k_{per}(x,x') = \sigma^2 \exp ( - \frac{2 \sin^2 (\pi || x - x' || / p) }{\ell^2} ) $
# The periodic kernel is a stationary kernel like the RBF kernel, but contains an additional parameter $p$ that controls the periodicity of the function.
#
#
#
# ## Prior
#
# We define the **prior** as a GP over the test set $X_*$, where each test point is treated as a random variable. In our example, we choose $|X_*|=N=200$ linearly-spaced values from 0 to 250 as test set to get the prior $P_{X_*}$ before any data is observed. The prior has dimensionality $N$ and revolves around $\mu=0$. The covariance matrix $\Sigma_{**}$ is computed by applying the kernel function $k$ to the test points $X_*$, $\Sigma_{**} = k(X_*,X_*)$.
# To demonstrate realizations of a GP we implement the prior distribution as previously described with following hyperparameters:
# * RBF: $\sigma^2 = 3,~ \ell = 15$
# * Linear: $\sigma^2 = 3,~ \sigma_b^2 = 2,~ c = 0.5$
# * Periodic: $\sigma^2 = 3,~ \ell = 15,~ p = 25$
#
# and generate a random Gaussian vector $f_* \sim \mathcal{N}(\mu, k(X_*,X_*)) = \mathcal{N}(0,\Sigma_{**})$ to sample five functions from each Prior.

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnchoredText
import subprocess
from collections import defaultdict
from scipy.optimize import minimize
import scipy


def kernel_rbf(x, y, param):
    """ Radial Basis Function Kernel 
    
    Args:
    x : First input vector of kernel (N,1)
    y : Second input vector of kernel (N,1)
    param : dictionary
            Contains scale factor variance, and lengthscale ell
        
    Returns:
        Covariance matrix of each pairwise combination of set of points
    """
    variance = param['var']
    lengthscale = param['ell']
    # Euclidean distance between points
    eucdist = np.sum(x**2,1).reshape(-1,1) + np.sum(y**2,1) - 2*np.dot(x, y.T)
    return variance * np.exp(-0.5 * eucdist * 1/(lengthscale**2))
    
    
def kernel_linear(x, y, param):
    """ Linear Kernel
    """
    variance = param['var']
    variance_b = param['var_b']
    offset = param['off']
    return variance_b + variance * np.dot((x-offset), (y-offset).T)


def kernel_periodic(x, y, param):
    """ Periodic Kernel
    """
    variance = param['var']
    lengthscale = param['ell']
    period = param['per']
    return variance * np.exp(-(2*np.sin((np.pi * (x - y.T))/period)**2)/ (lengthscale**2))



# define all hyperparameters for all kernels
params = {'var': 3,
          'ell': 15,        # larger l -> less wiggles
          'var_b': 2,
          'off': 0.5,
          'per': 25}


# Test Data: N points from 0 to 15
N_s = 500
X_s = np.linspace(0, 250, N_s).reshape(-1,1)


# Priors using RBF, linear and periodic kernel
fig, ax = plt.subplots(1, 3, figsize=(16,4))

for i, kernel in enumerate([kernel_rbf, kernel_linear, kernel_periodic]):
    # compute mean and covariance
    mu_prior = np.zeros(X_s.shape)
    cov_prior = kernel(X_s, X_s, params)
    # sample 5 normals from GP prior and plot
    f_prior = np.random.multivariate_normal(mu_prior.ravel(), cov_prior, 5)
    #plt.subplot(1, 3, (i+1))
    for sample in f_prior:
        ax[i].plot(X_s, sample, lw=1.5, ls='-')
        #plt.title(f'Prior using {kernel.__name__}')
        at = AnchoredText(kernel.__name__, prop=dict(size=12), frameon=True, loc='upper left')
        at.patch.set_boxstyle("round,pad=0.,rounding_size=0.2")
        ax[i].add_artist(at)
        ax[i].set_xlabel('x*')
        ax[i].set_ylabel('f*', rotation=0)
plt.tight_layout()        
plt.show()
fig.savefig('../figures/other/Priors_kernels.png', dpi=300)

# %% [markdown]
# ## Combination of kernels
#
# It is possible to combine two (or more) kernels, what is especially useful when they are defined on different inputs to the function, or if we want to have more high-level structures in the model. A standard way is to **multiply** two kernels, then the resulting kernel will have high value only if both of the base kernels have a high value. You can think of it as an *AND* operation. In contrast, **adding** two kernels can be thought of as an *OR* operation. That means that the resulting kernel will have high value if either of the two base kernels have a high value [4].

# %%
def kernel_mult_r_l(x, y, param):
    """ Multiply RBF and Linear Kernel
    """
    return kernel_rbf(x, y, param) * kernel_linear(x, y, param)

def kernel_add_r_l(x, y, param):
    """ Add RBF and Linear Kernel
    """
    return kernel_rbf(x, y, param) + kernel_linear(x, y, param)

def kernel_mult_r_p(x, y, param):
    """ Multiply RBF and Linear Kernel
    """
    return kernel_rbf(x, y, param) * kernel_periodic(x, y, param)



fig, ax = plt.subplots(1, 2, figsize=(12,4))

# Priors using combinations of kernels
for i, kernel in enumerate([kernel_mult, kernel_add]):
    # compute mean and covariance
    mu_prior = np.zeros(X_s.shape)
    cov_prior = kernel(X_s, X_s, params)
    # sample 5 normals from GP prior and plot
    f_prior = np.random.multivariate_normal(mu_prior.ravel(), cov_prior, 5)
    for sample in f_prior:
        ax[i].plot(X_s, sample, lw=1.5, ls='-')
        #plt.title(f'Prior using {kernel.__name__}')
        at = AnchoredText(kernel.__name__, prop=dict(size=12), frameon=True, loc='upper left')
        at.patch.set_boxstyle("round,pad=0.,rounding_size=0.2")
        ax[i].add_artist(at)
        ax[i].set_xlabel('x*')
        ax[i].set_ylabel('f*', rotation=0)
plt.tight_layout()        
plt.show()
fig.savefig('../figures/other/Priors_kernels_comb.png', dpi=300)

# %% [markdown]
# ## Observations
#
#
#
# Now we want to incorporate knowledge from collected **training data**. First, we assume that we obtained perfect measurements and have *noise-free* observations. We get the training set $\{(x_i,f_i)|i=1,...,n\}$, consisting of inputs $X$ and function outputs $f$.
#
#
# We test the method on the popular **SIR model** used to study the spread of an epidemics. It models the dynamics of **S**usceptible, **I**nfected, and **R**ecovered individuals for a fixed population size $n$ [5]. We use a simple representation of the SIR model as a CTMC that includes stochasticity. Here, only two reactions (events) are considered [6]:
# - infection: S + I $\xrightarrow{k_i}$ 2 I
# - recovery:  I $\xrightarrow{k_r}$ R
#
#
# Our goal is to show the applicability of GPR on a simple example for predicting a collective response. Therefore, we fix the two rates, $k_i = 0.001$ and $k_r = 0.1$, and the initial number of infections, $I_0 = 5$, and want to infer the final number of infections for different population sizes.
#
#
# In the following shell, we invoke the model-checking tool *PRISM* to run the SIR model for different population sizes $n = X = [25, 50, 75, 100, 125, 150, 175, 200]$. As a result, *PRISM* saves the number of susceptible, infected and recovered individuals after $t=120$ seconds. This means, for our training inputs $X=n$ we get the simulated outputs $f=R[120]$ (final number of recovered people, since in this simple model this is equal to the number of infections during the epidemics).

# %%
# number of simulated paths for each population size
num_paths = 100
# population sizes for training data
pop_sizes = np.arange(25, 225, 25)

# %%
# PRISM - ONLY RUN TO SIMULATE NEW DATA
# simulate chain with Prism and save paths
for p in pop_sizes:
    for i in range(0, num_paths):
        result = "/Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_" + str(p) + "_path_" + str(i) + ".txt"
        resultfile = open(result ,"w")
        resultfile.close()
        resultfile = open(result, "r+")
        prismcommand = "/Applications/prism-4.7-src/prism/bin/prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=" + str(p) + " -simpath changes=true,time=120 " + result + " -simpathlen 10000"
        prismprocess = subprocess.check_call(prismcommand, stdin=None, stdout=None , stderr=None, shell=True)
        resultfile.close()
# Out:
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:17 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_0.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 125 steps, total time 120.3991411283518 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_0.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:17 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_1.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 102 steps, total time 121.17955924879462 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_1.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:17 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_2.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 85 steps, total time 121.16000885206529 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_2.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:17 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_3.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 95 steps, total time 121.77777432232065 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_3.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:18 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_4.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 121 steps, total time 121.1699815984875 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_4.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:18 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_5.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 135 steps, total time 120.49978268817196 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_5.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:18 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_6.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 127 steps, total time 120.04488314477733 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_6.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:18 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_7.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 97 steps, total time 120.41826097175387 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_7.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:18 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_8.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 107 steps, total time 120.50682001540615 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_8.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:18 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_9.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 99 steps, total time 121.21440049095989 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_9.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:19 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_10.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 117 steps, total time 120.3704766138956 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_10.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:19 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_11.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 102 steps, total time 120.65355691605828 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_11.txt)
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:19 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_12.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 103 steps, total time 122.48385079065416 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_12.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:19 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_13.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 126 steps, total time 120.61169335187657 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_13.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:19 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_14.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 113 steps, total time 121.4449390219829 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_14.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:19 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_15.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 105 steps, total time 120.62668632766989 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_15.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:20 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_16.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 107 steps, total time 120.35084241488428 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_16.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:20 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_17.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 116 steps, total time 120.49724122229506 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_17.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:20 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_18.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 96 steps, total time 120.09605806123865 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_18.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:20 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_19.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 93 steps, total time 120.27165331191169 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_19.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:20 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_20.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 92 steps, total time 122.2665052813617 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_20.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:20 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_21.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 128 steps, total time 120.25579156327233 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_21.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:21 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_22.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 117 steps, total time 120.63716790230245 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_22.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:21 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_23.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 46 steps, total time 123.87988631706396 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_23.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:21 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_24.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 86 steps, total time 120.77354486342855 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_24.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:21 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_25.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 104 steps, total time 120.09216095705425 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_25.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:21 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_26.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 106 steps, total time 120.05078320229447 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_26.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:21 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_27.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 115 steps, total time 121.40656123289217 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_27.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:22 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_28.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 94 steps, total time 120.0952866727768 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_28.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:22 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_29.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 98 steps, total time 121.40799492276959 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_29.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:22 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_30.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 117 steps, total time 121.55854940113426 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_30.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:22 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_31.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 103 steps, total time 120.24441532410518 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_31.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:22 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_32.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 135 steps, total time 120.44538538979253 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_32.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:22 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_33.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 82 steps, total time 120.13022935208917 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_33.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:23 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_34.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 105 steps, total time 123.36645454586707 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_34.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:23 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_35.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 106 steps, total time 120.77757059647175 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_35.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:23 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_36.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 77 steps, total time 120.81727299269556 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_36.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:23 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_37.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 95 steps, total time 122.62351458622834 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_37.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:23 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_38.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 100 steps, total time 120.34121177013859 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_38.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:23 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_39.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 87 steps, total time 122.5046678556387 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_39.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:24 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_40.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 107 steps, total time 120.05392331090786 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_40.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:24 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_41.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 100 steps, total time 121.46701117995829 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_41.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:24 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_42.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 71 steps, total time 121.37225820252793 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_42.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:24 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_43.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 86 steps, total time 120.81923961727317 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_43.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:24 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_44.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 97 steps, total time 120.11073687600391 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_44.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:24 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_45.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 109 steps, total time 120.55536125077835 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_45.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:25 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_46.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 62 steps, total time 120.83474641167288 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_46.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:25 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_47.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 103 steps, total time 120.39323797907235 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_47.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:25 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_48.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 111 steps, total time 120.99612362065143 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_48.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:25 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_49.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 66 steps, total time 120.09962815836951 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_49.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:25 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_50.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 134 steps, total time 120.97754298552547 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_50.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:25 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_51.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 123 steps, total time 121.32878414188865 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_51.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:26 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_52.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 113 steps, total time 121.95598449801626 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_52.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:26 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_53.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 97 steps, total time 120.07081622472207 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_53.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:26 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_54.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 110 steps, total time 122.53120119049927 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_54.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:26 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_55.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 68 steps, total time 120.58089574460702 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_55.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:26 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_56.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 106 steps, total time 120.3409367327261 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_56.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:26 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_57.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 125 steps, total time 123.6440067250324 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_57.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:27 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_58.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 102 steps, total time 123.26368518985183 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_58.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:27 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_59.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 105 steps, total time 120.87102933158081 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_59.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:27 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_60.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 118 steps, total time 122.16804022190878 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_60.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:27 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_61.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 77 steps, total time 120.65745718084487 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_61.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:27 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_62.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 109 steps, total time 120.76807354106434 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_62.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:27 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_63.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 90 steps, total time 120.47431053471936 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_63.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:28 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_64.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 93 steps, total time 121.1013938267309 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_64.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:28 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_65.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 107 steps, total time 120.35416904389967 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_65.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:28 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_66.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 118 steps, total time 120.7815233948018 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_66.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:28 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_67.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 108 steps, total time 120.1660036642684 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_67.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:17:28 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=25 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_25_path_68.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# ...
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 333 steps, total time 147.89692642700626 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_77.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:30 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_78.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 305 steps, total time 125.71046783435438 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_78.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:30 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_79.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 278 steps, total time 121.88522299796078 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_79.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:31 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_80.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 321 steps, total time 129.3967800447096 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_80.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:31 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_81.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 305 steps, total time 120.9299239282975 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_81.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:31 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_82.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 313 steps, total time 135.97906556101262 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_82.txt)
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:31 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_83.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 307 steps, total time 120.4822541469188 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_83.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:31 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_84.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 255 steps, total time 122.06093753013347 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_84.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:31 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_85.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 319 steps, total time 120.18999887262103 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_85.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:32 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_86.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 306 steps, total time 120.24252128332957 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_86.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:32 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_87.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 289 steps, total time 120.44352535311064 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_87.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:32 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_88.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 328 steps, total time 120.80471358401361 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_88.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:32 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_89.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 352 steps, total time 122.2699787386968 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_89.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:32 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_90.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 355 steps, total time 121.17311367435535 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_90.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:32 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_91.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 328 steps, total time 120.85891038860179 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_91.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:33 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_92.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 312 steps, total time 120.62435684116747 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_92.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:33 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_93.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 347 steps, total time 120.55164168890313 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_93.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:33 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_94.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
# Generating random path with time limit 120.0...
#
# Generated path: 337 steps, total time 123.13325743544581 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_94.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:33 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_95.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 355 steps, total time 123.02907102405321 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_95.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:33 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_96.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 282 steps, total time 120.0402919444351 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_96.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:34 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_97.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 347 steps, total time 123.39005201762467 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_97.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:34 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_98.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 328 steps, total time 121.72530370005899 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_98.txt)
#
# PRISM
# =====
#
# Version: 4.7
# Date: Mon Jan 31 11:19:34 CET 2022
# Hostname: Julias-MacBook-Pro.local
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm -const maxPop=200 -simpath 'changes=true,time=120' /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_99.txt -simpathlen 10000
#
# Parsing model file "/Users/juliaklein/Documents/uni/MasterThesis/models/sir.pm"...
#
# Type:        CTMC
# Modules:     SIR
# Variables:   popS popI popR
#
# Generating random path with time limit 120.0...
#
# Generated path: 327 steps, total time 120.4037205949736 (exported to /Users/juliaklein/Documents/uni/MasterThesis/data/sir/sir_200_path_99.txt)

# %% [markdown]
# For a population of size $n$, we have $n+1$ possible outcomes $o=(0,1,...,n) \in \mathbb{N}^{n+1}$ with the associated probabilities $p=(p_0,...,p_n) \in \mathbb{R}^{n+1}$. Below you can see the resulting histograms of recovered individuals for each of the 8 population sizes.
#
# Since it is difficult to process and predict a whole distribution, we start by computing the first statistical moment of the histogram, its mean value
#
# $$\overline{x} = \sum_i (p_io_i)$$
#
# to predict the collective response of other population sizes.
#
# Therefore, our training data consists of inputs (population size) $X=[25,50,75,100,125,150,175,200]$ and outputs (mean values) $f=[6.03, 8.82, 13.35, 26.36, 41.95, 66.69, 111.4, 150.96]$, or mean proportions $[0.2412, 0.1764, 0.178, 0.2636, 0.3356, 0.4446, 0.6366, 0.7548]$.

# %%
# save number of recovered people for each population size and experiment
recovered = defaultdict(list)

# read outcomes for all population sizes and compute number of satisfactions
for dirpath, dirs, files in os.walk("/Users/juliaklein/Documents/uni/MasterThesis/data/sir"):
    for file in files:
        p = int((file.split("_")[1]))
        with open(os.path.join(dirpath, file), 'r') as f:
            data = f.readline()
            for last_line in f:
                pass
            R = int(last_line.split(" ")[5])
            recovered[p].append(R)

means1, means2, probs, obs = [], [], [], []
i=0

# plot histogram training data
print('\n--------------------------------------- Normalised representation ---------------------------------------')
plt.figure(figsize=(16, 6))
for key in sorted(recovered):
    outcomes, counts = np.unique(recovered[key], return_counts = True)
    prob = counts / np.sum(counts)
    proportions = outcomes / key
    
    means1.append(round(np.sum(prob * outcomes), 4))    # integers of number of recovered individuals
    means2.append(round(np.sum(prob * proportions), 4)) # recovered individuals as proportion of population

    probs.append(prob)
    obs.append(proportions)
    
    plt.subplot(2,4,(i+1))
    plt.hist([r/key for r in recovered[key]], bins=np.arange(0,1.1,0.05), width=0.04, color='darkblue')    
    plt.xlabel('Proportion of Recovered')
    plt.ylabel('Frequency')
    plt.title(f'Population size: {key}')
    plt.tight_layout()
    i+=1
plt.show()

print('Mean values:      ', means1)
print('Mean proportions: ', means2)

sample_size = np.sum(counts)  

# Training data
X = pop_sizes.reshape(-1,1)
N = len(X)
f = np.array(means2).reshape(-1,1)

plt.figure(figsize=(6,4))
plt.plot(X, f, 'o', ms=8, color='darkblue')
plt.xlim((0, 225))
plt.ylim((0,1))
plt.xlabel('$X$')
plt.ylabel('$f$', rotation=0)
plt.show()
# Out:
# --------------------------------------- Normalized representation ---------------------------------------
# Mean values:       [6.03, 8.82, 13.35, 26.36, 41.95, 66.69, 111.4, 150.96]
# Mean proportions:  [0.2412, 0.1764, 0.178, 0.2636, 0.3356, 0.4446, 0.6366, 0.7548]

# %% [markdown]
# ## Derive Posterior Distribution
#
# Given the test set $X_*$ and training data $\{X,~ f\}$, we want to predict the function outputs $f_*$.
#
#
# The *joint distribution* of training and test outputs is: $\begin{bmatrix} f \\ f_* \end{bmatrix} \sim \mathcal{N} \begin{pmatrix} \begin{bmatrix} \mu \\ \mu_* \end{bmatrix}, \begin{bmatrix} \Sigma & \Sigma_* \\ \Sigma_*^T & \Sigma_{**} \end{bmatrix} \end{pmatrix} $,
#
# where $\Sigma$ denotes the covariance matrix evaluated at all paris of training points $X$, $\Sigma_*$ at training and test points, and $\Sigma_{**}$ at test points $X_*$, and $\mu=\mu_*=0$.
#
# The **posterior distribution** $p(f_*|X_*,X,f)$ can be derived by *conditioning* the joint Gaussian prior distributions on the observations. We get:
#
# \begin{align}
# f_*|X_*,X,f \sim \mathcal{N}(\Sigma_*^T \Sigma^{-1}f,~ \Sigma_{**} - \Sigma_*^T \Sigma^{-1} \Sigma_*)
# \label{eq:post}\tag{1}
# \end{align}
#
# The function values $f_*$ can be sampled from the joint posterior distribution by evaluating the mean and covariance matrix and generating samples.
#
#
# Hint, according to [2]: For reasons of numerical stability, it is unwise to directly invert $\Sigma$. More robust alternative: Cholesky decomposition, $\Sigma = LL^T$. Then, solve for $\alpha = \Sigma^{-1}f = L^{-T}L^{-1}f$. Compute mean using $\Sigma_*^T \alpha$ and variance using $\Sigma_{**} - \Sigma_*^T L^{-T} L^{-1} \Sigma_*$.
#
#
#
#
#
# Here, we sample from the GP posterior after conditioning on the previously mentioned observations $f$. The shaded area represents the uncertainty as the $95\%$ confidence region (pointwise mean $\pm$ two times the standard deviation for each input value).
#
# Note that the variance is zero in a noise-free model, and that all functions go directly through the training points [2].

# %%
def posterior(X, X_s, f, kernel=kernel_rbf, params=params, noise=1e-15):
    """ Derive Posterior Distribution using Equation (1)
    
    Args:
        X: Training Data inputs (N,1) 
        X_s: Test Data inputs (Ns,1)
        f: Training Data outputs (N,1)
        kernel: Kernel function to compute covariance matrices, default RBF
        params: dictionary with hyperparameters for kernels
        noise: variance of noisy observations, default 1e-15 for numerical stability
        
    Returns:
        mu_s: Mean vector of posterior distribution (Ns,1)
        sigma_s: Covariance matrix of posterior distribution (Ns,Ns)
        
    """
    N, N_s = len(X), len(X_s)

    cov = kernel(X, X, params) + noise * np.eye(N)             
    cov_s = kernel(X, X_s, params)                             
    cov_ss = kernel(X_s, X_s, params)                          
    
    # Cholesky decomposition for numerically stable matrix inversion
    L = np.linalg.cholesky(cov + 1e-5 * np.eye(N))
    alpha_1 = np.linalg.solve(L, f)
    alpha = np.linalg.solve(L.T, alpha_1)
    mu_s = cov_s.T.dot(alpha)
    
    v = np.linalg.solve(L, cov_s)
    sigma_s = cov_ss - v.T.dot(v)
    
    # without Cholesky:
    #mu_s = cov_s.T.dot(np.linalg.inv(cov)).dot(f)
    #sigma_s = cov_ss - cov_s.T.dot(np.linalg.inv(cov)).dot(cov_s)
    
    return mu_s, sigma_s



def plot_gp(mu, cov, X_s, X=None, f=None, samples=[], ax0=plt, pred=7):
    """ Plot GP with mean function & uncertainty
    Adapted from: https://github.com/krasserm/bayesian-machine-learning/blob/dev/gaussian-processes/gaussian_processes_util.py
    
    Args:
        mu: Mean vector of (posterior) distribution (Ns,1)
        cov: Covariance matrix of posterior distribution (Ns,Ns)
        X_s: Test Data inputs (Ns,1)
        X: Training Data inputs (N,1)
        f: Training Data outputs (N,1)
        samples: Drawn samples from GP (5,Ns)
        ax0: Plot to draw GP on
        pred: Specifies a test point with its prediction, default 7
        
    """
    X_s = X_s.ravel()
    mu = mu.ravel()
    uncertainty = 1.96 * np.sqrt(np.diag(cov))
        
    ax0.fill_between(X_s, mu + uncertainty, mu - uncertainty, alpha=0.2)
    ax0.plot(X_s, mu, '--', color='darkblue', lw=3, label='Mean')
    plt.xlabel('$X_*$')
    plt.ylabel('$f_*$', rotation=0)
    for i, sample in enumerate(samples):
        ax0.plot(X_s, sample, lw=1.5)
    if X is not None:
        ax0.plot(X, f, 'o', ms=8, color='darkblue')
   #ax0.legend()



# Noise free Training data
X = pop_sizes.reshape(-1,1)
N = len(X)
f = np.array(means2).reshape(-1,1)

# define all hyperparameters for all kernels
params = {'var': 0.3,
          'ell': 15,        
          'var_b': 1,
          'off': 0.5,
          'per': 25}


# Posterior using all kernels & combinations
fig, ax = plt.subplots(2, 3, figsize=(16,8))

for i, kernel in enumerate([kernel_rbf, kernel_linear, kernel_periodic, kernel_mult_r_l, kernel_add_r_l, kernel_mult_r_p]):
    # compute mean and covariance of the posterior distribution and draw 5 samples
    mu_post, cov_post = posterior(X, X_s, f, kernel, params)
    samples = np.random.multivariate_normal(mu_post.ravel(), cov_post, 5)
    idx_pred = np.absolute(X_s-7).argmin()
    #plt.subplot(2,3,(i+1))
    ax = ax.flatten()
    plot_gp(mu_post, cov_post, X_s, X, f, samples, ax[i])
    at = AnchoredText(kernel.__name__, prop=dict(size=12), frameon=True, loc='upper left')
    at.patch.set_boxstyle("round,pad=0.,rounding_size=0.2")
    ax[i].add_artist(at)
#    plt.title(f'Posterior using {kernel.__name__}')
    # compute prediction for x* = 7
#    \n f_*[7] = {mu_post[idx_pred]}')
plt.tight_layout()        
plt.show()
fig.savefig('../figures/sir/SIR_GPR_posterior.png', dpi=300)

# %% [markdown]
# ## Noisy Observations
#
# Normally, we do not have perfect data, but some noise available due to measurement errors, for example. In this case, the training points are only approximated and the variance is not zero at those training points.
# If we assume that the observational noise is normally distributed, the posterior is still a GP and the inference analytically tractable.
# We assume $y = f(x) + \epsilon$ with $f \sim GP(0,\Sigma)$ and $\epsilon \sim \mathcal{N}(0, \sigma_f^2I)$. The noise variance $\sigma_f^2$ is an additional parameter of the likelihood and independently added to each observation. We get:
#
# $p(y|f) = \mathcal{N}(y|f,\sigma_f^2I).$
#
# We can then write the joint distribution of training and test values as
#
# $$ \begin{bmatrix} y \\ f_* \end{bmatrix} \sim \mathcal{N} \begin{pmatrix} 0, \begin{bmatrix} \Sigma_y & \Sigma_* \\ \Sigma_*^T & \Sigma_{**} \end{bmatrix} \end{pmatrix} $$
#
# with $\Sigma_y := \Sigma + \sigma_f^2I$.
#
# Again, we derive the conditional distribution and get
#
# $$ f_*|X_*,X,y \sim \mathcal{N}(\Sigma_*^T \Sigma_y^{-1} y,~ \Sigma_{**} - \Sigma_*^T\Sigma_y^{-1} \Sigma_* )$$
#
# as our posterior distribution [2], from which we sample like in the example with noise-free training data. Since we have real observations, we can compute the margins of error for our data points and take them as the noise $\sigma_f$. The margin for one mean estimate $\overline{x}$ is computed as follows:
#
# $$ \Delta = t_{N-1} \frac{s}{\sqrt{N}}, $$
#
# where $s$ is the standard deviation of the histogram, $s = \sqrt{\sum_i p_i (o_i - \overline{x})^2}$, and $t_{N-1}$ the critical t-value from the t-distribution with N – 1 degrees of freedom.

# %%
def comp_sd(probs, obs, mu):
    """ Standard deviation of histogram
    Args:
        probs: probabilities (N,1)
        obs: observations (N,1)
        mu: mean value 
    Returns:
        Standard deviation s according to equation above  
        
    """
    return np.sqrt(np.sum(probs * (obs - mu)**2))


def comp_margin(t, sd, N):
    """ Margin of error for mean estimate of histogram
    Args:
        t: critical t-value with N-1 degrees of freedom
        sd: standard deviation of histogram
        N: sample size
    Returns:
        Margin delta for mean estimate
        
    """
    return t * (sd / np.sqrt(N))


# compute noise as 95% margins of mean for all histograms
sigma_f = np.array([comp_margin(t = 1.962, sd = comp_sd(p, o, f[i]), N = sample_size) for (p, o, i) \
                   in zip(probs, obs, np.arange(len(f)))])

print('Margins of mean values: ', sigma_f)


# Posterior using all kernels with noisy training data
fig, ax = plt.subplots(2, 3, figsize=(16,8))

for i, kernel in enumerate([kernel_rbf, kernel_linear, kernel_periodic, kernel_mult_r_l, kernel_add_r_l, kernel_mult_r_p]):
    # compute mean and covariance of the posterior distribution and draw 5 samples for noisy observations
    mu_post, cov_post = posterior(X, X_s, f, kernel, params, noise=sigma_f)
    samples = np.random.multivariate_normal(mu_post.ravel(), cov_post, 5)
    #plt.subplot(2,3,(i+1))
    ax = ax.flatten()
    plot_gp(mu_post, cov_post, X_s, X, f, samples, ax[i])
    at = AnchoredText(kernel.__name__, prop=dict(size=12), frameon=True, loc='upper left')
    at.patch.set_boxstyle("round,pad=0.,rounding_size=0.2")
    ax[i].add_artist(at)
    plt.title(f'Posterior using {kernel.__name__}')
plt.tight_layout()        
plt.show()
fig.savefig('../figures/sir/SIR_GPR_noise.png', dpi=300)
# Out:
# Margins of mean values:  [0.00957681 0.01231386 0.02010196 0.03129562 0.03843846 0.04308056
#  0.04293875 0.02845202]

# %% [markdown]
# ## Optimise hyperparameters
#
# We consider an empirical Bayes approach to maximize the marginal likelihood
#
# $$ p(y|X) = \int p(y|f,X)p(f|X)df$$
# in order to optimise the kernel's hyperparameters.
#
# The marginal likelihood can be rewritten as
# \begin{align}
# \text{log}~ p(y|X) = \text{log}~ \mathcal{N}(y|0,\Sigma_y) = - \frac{1}{2} y \Sigma_y^{-1}y - \frac{1}{2} \text{log}~ |\Sigma_y| - \frac{1}{2} N \text{log}~(2\pi),
# \label{eq:post}\tag{2}
# \end{align}
#
# where the first term is a data fit term, the second term a model complexity term, and the third term a constant.
#
# Again, we can use Cholesky decomposition for numerical stability and rewrite the log marginal likelihood:
# $ \text{log}~ p(y|X) = - \frac{1}{2} y^T \alpha - \sum_i \text{log}~ L_{ii} - \frac{1}{2} N \text{log}~(2\pi) $.
#
# Now we want to optimise the hyperparameters by minimising the negative log marginal likelihood with respect to the kernel parameters [2].

# %%
def nll(X, f, kernel=kernel_rbf, noise=1e-2):
    """ Compute negative log marginal likelihood,
    stable implementation using Cholesky decomposition
    
    Args:
        X: Training data input (N,1)
        f: Training data output (N,1)
        kernel: Kernel function for which the parameters should be optimized, default RBF
        noise: small value for numerical stability in matrix calculations
        
    Returns:
        nll_stable: negative log marginal likelihood
    
    """
    
    f = f.ravel()

    # naive implementation of Equation (2)
    #cov_y = kernel(X, X, params) + noise**2 * np.eye(N)
    #return 0.5 * f.dot(np.linalg.inv(cov_y).dot(f)) + \
    #       0.5 * np.log(np.linalg.det(cov_y)) + \
    #       0.5 * N * np.log(2*np.pi)
    
    def nll_stable(theta):
        params = {'var':   theta[0],
                  'ell':   theta[1],        
                  'var_b': theta[2],
                  'off':   theta[3],
                  'per':   theta[4]}
        cov_y = kernel(X, X, params)     
        L = np.linalg.cholesky(cov_y + noise**2 * np.eye(N))
        alpha_1 = np.linalg.solve(L, f)
        alpha = np.linalg.solve(L.T, alpha_1)
        
        return 0.5 * f.T.dot(alpha) + \
               np.sum(np.log(np.diagonal(L))) + \
               0.5 * N * np.log(2*np.pi)
    
    return nll_stable

    
fig, ax = plt.subplots(2, 3, figsize=(16,8))

# Optimise parameters for all kernels: minimize nll 
for i, kernel in enumerate([kernel_rbf, kernel_linear, kernel_periodic, kernel_mult_r_l, kernel_add_r_l, kernel_mult_r_p]):
    res = minimize(nll(X, f, kernel=kernel, noise=sigma_f), [1, 10, 1, 1, 30],
                   bounds=((1e-2, None), (1e-2, None), (1e-2, None), (1e-2, None), (1e-2, None)),
                   method='L-BFGS-B')

    # compute posterior with optimized parameters
    var_opt, ell_opt, var_b_opt, off_opt, per_opt = res.x
    params = {'var':   var_opt,
              'ell':   ell_opt,        
              'var_b': var_b_opt,
              'off':   off_opt,
              'per':   per_opt}

    mu_s, cov_s = posterior(X, X_s, f, kernel, params=params, noise=sigma_f)
    #plt.subplot(2,3,(i+1))
    ax = ax.flatten()
    plot_gp(mu_s, cov_s, X_s, X, f, [], ax[i])
    at = AnchoredText(kernel.__name__, prop=dict(size=12), frameon=True, loc='upper left')
    at.patch.set_boxstyle("round,pad=0.,rounding_size=0.2")
    ax[i].add_artist(at)
    #plt.title(f'Posterior with optimized hyperparameters  \n{kernel.__name__}')
plt.tight_layout()        
plt.show()

fig.savefig('../figures/sir/SIR_GPR_optim.png', dpi=300)

# %% [markdown]
# # Leave-one-out cross-validation (LOOCV)
#
# To estimate the performance of the different models (here kernels), we use k-fold cross-validation, where the training data is split into $k$ folds. In our case, $k=N$ is the most appropriate method, also called Leave-one-out cross-validation, because of the small size of the data set. Here, we train on all data cases except for $i$ in fold $i$, and then test on $i$. We leave one data point out from the training set and evaluate the prediction of the model for this data point. Each data point will be used as a test point, all other together as test set. By computing summary statistics, we get an overall evaluation of the model's performance. Another reason why we use LOOCV is due to the advantage of giving reliable and unbiased estimates of the model performance [2].

# %%
def loocv(X, f, kernel=kernel_rbf, noise=1e-2):
    """ Leave-one-out cross-validation to compare model performances
    For each input data point, remove it from training data, then:
        Optimize hyperparameters of specified kernel 
        Derive posterior distribution with optimized parameters
        Obtain prediction for left-out data point
    
    Args:
        X: Training data input (N,1)
        f: Training data output (N,1)
        kernel: Kernel function to validate, default RBF
        
    Returns:
        predictions: List of predictions of left-out training data points  
        
    """
    predictions = []
    N = len(X) - 1
    for leave_out in range(N+1):
        X_new = np.delete(X, leave_out).reshape(-1,1)
        f_new = np.delete(f, leave_out).reshape(-1,1)
        if len(noise)>1:
            noise_new = np.delete(noise, leave_out).reshape(-1,1)
        else:
            noise_new = noise

        res = minimize(nll(X_new, f_new, kernel=kernel, noise=noise_new), [1, 1, 1, 1, 1],
                   bounds=((1e-2, None), (1e-2, None), (1e-2, None), (1e-2, None), (1e-2, None)),
                   method='L-BFGS-B')
        
        var_opt, ell_opt, var_b_opt, off_opt, per_opt = res.x
        params = {'var':   var_opt,
                  'ell':   ell_opt,        
                  'var_b': var_b_opt,
                  'off':   off_opt,
                  'per':   per_opt}
        mu_s, cov_s = posterior(X_new, X_s, f_new, kernel, params=params, noise=noise_new)
        
        # prediction for left out data point
        idx_pred = np.absolute(X_s-X[leave_out]).argmin()
        predictions.append(mu_s.item(idx_pred))

    return predictions
    
    
# compute LOOCV for all kernels
print(f'True parameters: {f.reshape(1,-1)}')
for i, kernel in enumerate([kernel_rbf, kernel_linear, kernel_periodic, kernel_mult_r_l, kernel_add_r_l, kernel_mult_r_p]):
    # decrease N to account for smaller training set in LOOCV
    N = X.size-1    
    predictions = loocv(X=X, f=f, kernel=kernel, noise=sigma_f)
    print(f'\nPredictions for {kernel.__name__}: {predictions}')
    l2dist = np.linalg.norm(f.reshape(1,-1) - predictions)
    print(f'MSE to true data points: {l2dist}')
# Out:
# True parameters: [[0.2412 0.1764 0.178  0.2636 0.3356 0.4446 0.6366 0.7548]]
#
# Predictions for kernel_rbf: [1.1144011541740777e-136, 3.824405545953353e-136, 1.859001861282135e-135, 7.930715858171734e-135, 3.545235915584034e-134, 7.804214026693349e-135, 2.8169165451493095e-135, 1.1127155977302312e-135]
# MSE to true data points: 1.2148014158701002
#
# Predictions for kernel_linear: [0.03140264029389073, 0.21436524386683686, 0.2906716838460852, 0.3595611082685082, 0.4385809401865117, 0.5051280446787132, 0.5474365129048238, 0.5631590996638351]
# MSE to true data points: 0.3553938869329484
#
# Predictions for kernel_periodic: [0.15255016995628679, 0.2740393496315192, 0.2137095319728992, 0.2080308812496856, 0.6175941679171526, 0.21029175173579595, 0.22449293611547255, 0.5098435291705923]
# MSE to true data points: 0.6212988839876561
#
# Predictions for kernel_mult_r_l: [1.7607638345748057e-136, 4.4343803656441416e-136, 1.2637140985670269e-136, 5.196993576889719e-135, 2.9319417801934023e-134, 1.1995471150758857e-134, 4.397850544203221e-135, 1.7602591459199758e-135]
# MSE to true data points: 1.2148014158701002
#
# Predictions for kernel_add_r_l: [-0.00425364731772504, 0.18501609603833913, 0.27367597183302905, 0.35244074140075554, 0.43567070388121465, 0.5135989646354346, 0.5698480010873936, 0.6046823722283534]
# MSE to true data points: 0.34515856274182954
#
# Predictions for kernel_mult_r_p: [1.0609650906542183e-136, 3.1571801882806404e-136, 1.2291168477393752e-135, 3.96443864897008e-135, 1.3001203398097585e-134, 3.901202388629535e-135, 1.8624615526312807e-135, 9.18585540707679e-136]
# MSE to true data points: 1.2148014158701002

# %% [markdown]
# # References
#
# [1] Jochen  Görtler,  Rebecca  Kehlbeck,  and  Oliver  Deussen.   A  visual  exploration  of gaussian processes. Distill, 4:e17, 2019.
# [2] Kevin P. Murphy. Machine Learning: a probabilistic perspective.  MIT press, 2012.
# [3] Carl Edward Rasmussen. Gaussian processes in machine learning. In Summer school on machine learning, Springer, 2003.
# [4] Duvenaud, David. Automatic model construction with Gaussian processes. Diss. University of Cambridge, 2014.
# [5] William Ogilvy Kermack, and Anderson G. McKendrick. A contribution to the mathematical theory of epidemics. Proceedings of the royal society of london. Series A, Containing papers of a mathematical and physical character, 115(772), 1927.
# [6] Milan Češka, Petr Pilař, Nicola Paoletti, Lubos Brim, and Marta Kwiatkowska. PRISM-PSY: precise GPU-accelerated parameter synthesis for stochastic systems. In International Conference on Tools and Algorithms for the Construction and Analysis of Systems (pp. 367-384). Springer, Berlin, Heidelberg, 2016.
